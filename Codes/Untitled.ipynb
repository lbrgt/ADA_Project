# %%
import findspark
findspark.init()
import matplotlib.pyplot as plt
from pyspark.sql.types import TimestampType
from pyspark.sql.types import DateType
import datetime as dt
from pyspark.sql.functions import *
import pandas as pd
import numpy as np
import scipy as sp
from pyspark.sql import *
# %matplotlib inline

spark = SparkSession.builder.getOrCreate()

# %%
filename = '../Data/sources_by_country.csv'

# %%
loc_df = pd.read_csv(filename)

# %%
loc_df
# Out:
#                  0-100.it  IT           Italy
# 0                 0-50.ru  RS          Russia
# 1             0-60mag.com  US   United States
# 2              0-debt.com  US   United States
# 3              000fff.org  US   United States
# 4            000space.com  UK  United Kingdom
# 5              00221.info  SG         Senegal
# 6                  005.fi  FI         Finland
# 7            00news.co.kr  KS     South Korea
# 8             010info.com  CH           China
# 9               010seo.tk  TL         Tokelau
# 10                0123.cn  CH           China
# 11             013info.rs  RI          Serbia
# 12            01737.co.uk  UK  United Kingdom
# 13              01809.com  UP         Ukraine
# 14      01informatique.fr  FR          France
# 15              01net.com  FR          France
# 16               01net.it  IT           Italy
# 17            02051935.nl  NL     Netherlands
# 18                 021.rs  RI          Serbia
# 19            0223.com.ar  AR       Argentina
# 20           022china.com  CH           China
# 21              022ms.com  CH           China
# 22              023pos.cn  CH           China
# 23                0245.cc  CH           China
# 24            0260nyc.com  US   United States
# 25              027ws.com  CH           China
# 26         0297-online.nl  NL     Netherlands
# 27                0297.nl  NL     Netherlands
# 28              02blog.it  IT           Italy
# 29              02elf.net  GM         Germany
# ...                   ...  ..             ...
# 189514          zycko.com  UK  United Kingdom
# 189515           zyjjw.cn  CH           China
# 189516        zylstra.org  NL     Netherlands
# 189517            zyn.com  US   United States
# 189518          zynews.cn  CH           China
# 189519         zynews.com  CH           China
# 189520          zynga.com  US   United States
# 189521        zyrb.com.cn  CH           China
# 189522         zys.com.ru  RS          Russia
# 189523          zysgp.org  CH           China
# 189524          zytech.es  CH           China
# 189525   zythophile.co.uk  UK  United Kingdom
# 189526           zyuan.tk  TL         Tokelau
# 189527             zyy.sg  SN       Singapore
# 189528        zz.diena.lv  LG          Latvia
# 189529        zz.fjnet.cn  CH           China
# 189530              zz.lv  LG          Latvia
# 189531          zz.mnw.cn  CH           China
# 189532             zz7.it  IT           Italy
# 189533       zzap64.co.uk  UK  United Kingdom
# 189534      zzdgsx.com.cn  CH           China
# 189535       zzedu.net.cn  CH           China
# 189536        zzit.com.cn  CH           China
# 189537          zznews.cn  CH           China
# 189538      zznews.gov.cn  CH           China
# 189539   zzp-nederland.nl  NL     Netherlands
# 189540    zzpbarometer.nl  NL     Netherlands
# 189541        zzpn.gov.cn  CH           China
# 189542        zzrednet.cn  CH           China
# 189543         zzzptm.com  US   United States
#
# [189544 rows x 3 columns]
