# %%
from pyspark.sql import *
from pyspark.sql.types import *
spark = SparkSession.builder.getOrCreate()

# %%
not_english_mentions_df = spark.read.parquet("../Data/NotEnglishMentions.parquet")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o186.parquet.
# : org.apache.spark.sql.AnalysisException: Path does not exist: file:/Users/sinangokce/Desktop/ADA_Project/Data/NotEnglishMentions.parquet;
# ...

# %%
not_english_mentions_df.show()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-8-bf4b9037ddda> in <module>()
# ----> 1 not_english_mentions_df.show()
#
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/pyspark/sql/dataframe.py in show(self, n, truncate, vertical)
#     348         """
#     349         if isinstance(truncate, bool) and truncate:
# --> 350             print(self._jdf.showString(n, 20, vertical))
#     351         else:
#     352             print(self._jdf.showString(n, int(truncate), vertical))
#
# ~/anaconda3/envs/ada/lib/python3.6/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# ...
